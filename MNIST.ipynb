# %%
from sklearn.datasets import fetch_mldata

mnist = fetch_mldata('MNIST original')
mnist
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-70d948efaea0> in <module>
# ----> 1 from sklearn.datasets import fetch_mldata
#       2
#       3 mnist = fetch_mldata('MNIST original')
#       4 mnist
#
# ImportError: cannot import name 'fetch_mldata' from 'sklearn.datasets' (C:\Users\rlfal\Anaconda3\lib\site-packages\sklearn\datasets\__init__.py)
